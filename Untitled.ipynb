# %%
import spruthub

# %%
sh = spruthub.api('192.168.31.133:55555')

# %%
sh.auth('ghjkl@jdjd.ru', 'raspberry1')
# Out:
# '919jzFkvp1pSQ3DsE2qaYc5X'

# %%
links = sh.getAllLinks()
links
# Out:
# [{'linkId': 'ZigBee/00158D0001DEACAF/On/Boolean/1/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D0001DEACAF',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': 'true',
#   'params': '1/OnOff/State',
#   'aId': 32,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00019C8EA5/CurrentRelativeHumidity/Float/1/RelativeHumidity/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019C8EA5',
#   'characteristic': 'CurrentRelativeHumidity',
#   'type': 'Float',
#   'value': '71.0',
#   'params': '1/RelativeHumidity/Level',
#   'aId': 39,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D00019CB768/CurrentRelativeHumidity/Float/1/RelativeHumidity/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019CB768',
#   'characteristic': 'CurrentRelativeHumidity',
#   'type': 'Float',
#   'value': '46.7',
#   'params': '1/RelativeHumidity/Level',
#   'aId': 34,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D0001E542DB/MotionDetected/Boolean/1/OccupancySensing/State',
#   'controller': 'ZigBee',
#   'device': '00158D0001E542DB',
#   'characteristic': 'MotionDetected',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '1/OccupancySensing/State',
#   'aId': 19,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D0001E542DB/CurrentAmbientLightLevel/Integer/1/Illuminance/Level',
#   'controller': 'ZigBee',
#   'device': '00158D0001E542DB',
#   'characteristic': 'CurrentAmbientLightLevel',
#   'type': 'Integer',
#   'value': '717',
#   'params': '1/Illuminance/Level',
#   'aId': 19,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D00015F2577/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00015F2577',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '65',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 24,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'WirenBoard/wb-gpio/ContactSensorState/Integer/A2_IN',
#   'controller': 'WirenBoard',
#   'device': 'wb-gpio',
#   'characteristic': 'ContactSensorState',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'A2_IN',
#   'aId': 14,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'WirenBoard/hwmon/CurrentTemperature/Float/CPU Temperature',
#   'controller': 'WirenBoard',
#   'device': 'hwmon',
#   'characteristic': 'CurrentTemperature',
#   'type': 'Float',
#   'value': '59.257',
#   'params': 'CPU Temperature',
#   'aId': 7,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'WirenBoard/power_status/ContactSensorState/Integer/working on battery',
#   'controller': 'WirenBoard',
#   'device': 'power_status',
#   'characteristic': 'ContactSensorState',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'working on battery',
#   'aId': 5,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00019CB1C1/MotionDetected/Boolean/1/OccupancySensing/State',
#   'controller': 'ZigBee',
#   'device': '00158D00019CB1C1',
#   'characteristic': 'MotionDetected',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '1/OccupancySensing/State',
#   'aId': 30,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00019CB768/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019CB768',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '83',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 34,
#   'sId': 16,
#   'cId': 18},
#  {'linkId': 'ZigBee/00158D0001400613/BatteryLevel/Integer/1/Battery/Level',
#   'controller': 'ZigBee',
#   'device': '00158D0001400613',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '0',
#   'params': '1/Battery/Level',
#   'aId': 28,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D0001F4E28C/CurrentAmbientLightLevel/Integer/1/Illuminance/Level',
#   'controller': 'ZigBee',
#   'device': '00158D0001F4E28C',
#   'characteristic': 'CurrentAmbientLightLevel',
#   'type': 'Integer',
#   'value': '717',
#   'params': '1/Illuminance/Level',
#   'aId': 0,
#   'sId': 0,
#   'cId': 0},
#  {'linkId': 'WirenBoard/wb-gpio/ContactSensorState/Integer/A3_IN',
#   'controller': 'WirenBoard',
#   'device': 'wb-gpio',
#   'characteristic': 'ContactSensorState',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'A3_IN',
#   'aId': 9,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D0001F4E40F/On/Boolean/1/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D0001F4E40F',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': 'true',
#   'params': '1/OnOff/State',
#   'aId': 21,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00015B7511/SmokeDetected/Boolean/1/IasZone/State',
#   'controller': 'ZigBee',
#   'device': '00158D00015B7511',
#   'characteristic': 'SmokeDetected',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '1/IasZone/State',
#   'aId': 17,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'WirenBoard/wb-gpio/On/Integer/A1_OUT',
#   'controller': 'WirenBoard',
#   'device': 'wb-gpio',
#   'characteristic': 'On',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'A1_OUT',
#   'aId': 10,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00020B4692/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00020B4692',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '89',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 18,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D0001F4E40F/On/Boolean/3/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D0001F4E40F',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': None,
#   'params': '3/OnOff/State',
#   'aId': 0,
#   'sId': 0,
#   'cId': 0},
#  {'linkId': 'WirenBoard/buzzer/On/Integer/enabled',
#   'controller': 'WirenBoard',
#   'device': 'buzzer',
#   'characteristic': 'On',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'enabled',
#   'aId': 12,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D0001F4E415/On/Boolean/1/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D0001F4E415',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '1/OnOff/State',
#   'aId': 23,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00019CB1C1/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019CB1C1',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '55',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 30,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D00020B4692/SmokeDetected/Boolean/1/IasZone/State',
#   'controller': 'ZigBee',
#   'device': '00158D00020B4692',
#   'characteristic': 'SmokeDetected',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '1/IasZone/State',
#   'aId': 18,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00015F2577/ProgrammableSwitchEvent/Integer/1/OnOff/Event',
#   'controller': 'ZigBee',
#   'device': '00158D00015F2577',
#   'characteristic': 'ProgrammableSwitchEvent',
#   'type': 'Integer',
#   'value': '0',
#   'params': '1/OnOff/Event',
#   'aId': 24,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D000249C585/SmokeDetected/Boolean/1/IasZone/State',
#   'controller': 'ZigBee',
#   'device': '00158D000249C585',
#   'characteristic': 'SmokeDetected',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '1/IasZone/State',
#   'aId': 25,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/D0CF5EFFFE296124/Brightness/Integer/1/LevelControl/Level',
#   'controller': 'ZigBee',
#   'device': 'D0CF5EFFFE296124',
#   'characteristic': 'Brightness',
#   'type': 'Integer',
#   'value': None,
#   'params': '1/LevelControl/Level',
#   'aId': 0,
#   'sId': 0,
#   'cId': 0},
#  {'linkId': 'ZigBee/00158D00019CB768/CurrentTemperature/Float/1/Temperature/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019CB768',
#   'characteristic': 'CurrentTemperature',
#   'type': 'Float',
#   'value': '22.22',
#   'params': '1/Temperature/Level',
#   'aId': 34,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'WirenBoard/wb-gpio/ContactSensorState/Integer/A4_IN',
#   'controller': 'WirenBoard',
#   'device': 'wb-gpio',
#   'characteristic': 'ContactSensorState',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'A4_IN',
#   'aId': 13,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00022BC8F6/On/Boolean/2/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D00022BC8F6',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '2/OnOff/State',
#   'aId': 20,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00022BC8F6/On/Boolean/3/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D00022BC8F6',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '3/OnOff/State',
#   'aId': 20,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D00019F8D4A/CurrentRelativeHumidity/Float/1/RelativeHumidity/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019F8D4A',
#   'characteristic': 'CurrentRelativeHumidity',
#   'type': 'Float',
#   'value': '49.35',
#   'params': '1/RelativeHumidity/Level',
#   'aId': 33,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D00019F8D4A/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019F8D4A',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '79',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 33,
#   'sId': 16,
#   'cId': 18},
#  {'linkId': 'ZigBee/00158D00019C8EA5/CurrentTemperature/Float/1/Temperature/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019C8EA5',
#   'characteristic': 'CurrentTemperature',
#   'type': 'Float',
#   'value': '21.7',
#   'params': '1/Temperature/Level',
#   'aId': 39,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00015C7ACF/On/Boolean/1/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D00015C7ACF',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': 'true',
#   'params': '1/OnOff/State',
#   'aId': 38,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'WirenBoard/wb-gpio/On/Integer/A3_OUT',
#   'controller': 'WirenBoard',
#   'device': 'wb-gpio',
#   'characteristic': 'On',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'A3_OUT',
#   'aId': 3,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D0001F4E41C/On/Boolean/1/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D0001F4E41C',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '1/OnOff/State',
#   'aId': 22,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D0001F4E28C/On/Boolean/1/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D0001F4E28C',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': 'true',
#   'params': '1/OnOff/State',
#   'aId': 16,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00124B001EC8462E/On/Boolean',
#   'controller': 'ZigBee',
#   'device': '00124B001EC8462E',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '',
#   'aId': 15,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00015D24C8/MotionDetected/Boolean/1/OccupancySensing/State',
#   'controller': 'ZigBee',
#   'device': '00158D00015D24C8',
#   'characteristic': 'MotionDetected',
#   'type': 'Boolean',
#   'value': 'true',
#   'params': '1/OccupancySensing/State',
#   'aId': 29,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00015D24C8/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00015D24C8',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '59',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 29,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D00019F8B90/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019F8B90',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '81',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 35,
#   'sId': 16,
#   'cId': 18},
#  {'linkId': 'ZigBee/D0CF5EFFFE296124/On/Boolean/1/OnOff/State',
#   'controller': 'ZigBee',
#   'device': 'D0CF5EFFFE296124',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': 'true',
#   'params': '1/OnOff/State',
#   'aId': 40,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D0001F4E28C/MotionDetected/Boolean/1/OccupancySensing/State',
#   'controller': 'ZigBee',
#   'device': '00158D0001F4E28C',
#   'characteristic': 'MotionDetected',
#   'type': 'Boolean',
#   'value': 'true',
#   'params': '1/OccupancySensing/State',
#   'aId': 0,
#   'sId': 0,
#   'cId': 0},
#  {'linkId': 'ZigBee/00158D00019C8EA5/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019C8EA5',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '0',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 39,
#   'sId': 16,
#   'cId': 18},
#  {'linkId': 'ZigBee/00158D00019F8D4A/CurrentTemperature/Float/1/Temperature/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019F8D4A',
#   'characteristic': 'CurrentTemperature',
#   'type': 'Float',
#   'value': '20.14',
#   'params': '1/Temperature/Level',
#   'aId': 33,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'WirenBoard/wb-gpio/On/Integer/A2_OUT',
#   'controller': 'WirenBoard',
#   'device': 'wb-gpio',
#   'characteristic': 'On',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'A2_OUT',
#   'aId': 8,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D0001A2A8F1/CurrentRelativeHumidity/Float/1/RelativeHumidity/Level',
#   'controller': 'ZigBee',
#   'device': '00158D0001A2A8F1',
#   'characteristic': 'CurrentRelativeHumidity',
#   'type': 'Float',
#   'value': '36.5',
#   'params': '1/RelativeHumidity/Level',
#   'aId': 36,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D00015B7511/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00015B7511',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '67',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 17,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D00023D326B/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00023D326B',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '60',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 37,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D00011919BA/BatteryLevel/Integer/1/Battery/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00011919BA',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '0',
#   'params': '1/Battery/Level',
#   'aId': 27,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D0001A2A8F1/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D0001A2A8F1',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '81',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 36,
#   'sId': 16,
#   'cId': 18},
#  {'linkId': 'ZigBee/00158D00019F8B90/CurrentTemperature/Float/1/Temperature/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019F8B90',
#   'characteristic': 'CurrentTemperature',
#   'type': 'Float',
#   'value': '21.62',
#   'params': '1/Temperature/Level',
#   'aId': 35,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'WirenBoard/hwmon/CurrentTemperature/Float/Board Temperature',
#   'controller': 'WirenBoard',
#   'device': 'hwmon',
#   'characteristic': 'CurrentTemperature',
#   'type': 'Float',
#   'value': '39.25',
#   'params': 'Board Temperature',
#   'aId': 7,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'WirenBoard/wb-gpio/ContactSensorState/Integer/A1_IN',
#   'controller': 'WirenBoard',
#   'device': 'wb-gpio',
#   'characteristic': 'ContactSensorState',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'A1_IN',
#   'aId': 11,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D0001DEAEF2/On/Boolean/1/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D0001DEAEF2',
#   'characteristic': 'On',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '1/OnOff/State',
#   'aId': 31,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D0001400613/ContactSensorState/Boolean/1/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D0001400613',
#   'characteristic': 'ContactSensorState',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '1/OnOff/State',
#   'aId': 28,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D0001A2A8F1/CurrentTemperature/Float/1/Temperature/Level',
#   'controller': 'ZigBee',
#   'device': '00158D0001A2A8F1',
#   'characteristic': 'CurrentTemperature',
#   'type': 'Float',
#   'value': '24.93',
#   'params': '1/Temperature/Level',
#   'aId': 36,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'WirenBoard/wb-gpio/On/Integer/A4_OUT',
#   'controller': 'WirenBoard',
#   'device': 'wb-gpio',
#   'characteristic': 'On',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'A4_OUT',
#   'aId': 6,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D0001E542DB/BatteryLevel/Integer/1/BatteryXiaomi/Level',
#   'controller': 'ZigBee',
#   'device': '00158D0001E542DB',
#   'characteristic': 'BatteryLevel',
#   'type': 'Integer',
#   'value': '45',
#   'params': '1/BatteryXiaomi/Level',
#   'aId': 19,
#   'sId': 16,
#   'cId': 18},
#  {'linkId': 'ZigBee/00158D00011919BA/ContactSensorState/Boolean/1/OnOff/State',
#   'controller': 'ZigBee',
#   'device': '00158D00011919BA',
#   'characteristic': 'ContactSensorState',
#   'type': 'Boolean',
#   'value': 'false',
#   'params': '1/OnOff/State',
#   'aId': 27,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'ZigBee/00158D00019F8B90/CurrentRelativeHumidity/Float/1/RelativeHumidity/Level',
#   'controller': 'ZigBee',
#   'device': '00158D00019F8B90',
#   'characteristic': 'CurrentRelativeHumidity',
#   'type': 'Float',
#   'value': '46.57',
#   'params': '1/RelativeHumidity/Level',
#   'aId': 35,
#   'sId': 13,
#   'cId': 15},
#  {'linkId': 'ZigBee/00158D00023D326B/ProgrammableSwitchEvent/Integer/1/OnOff/Event',
#   'controller': 'ZigBee',
#   'device': '00158D00023D326B',
#   'characteristic': 'ProgrammableSwitchEvent',
#   'type': 'Integer',
#   'value': '0',
#   'params': '1/OnOff/Event',
#   'aId': 37,
#   'sId': 10,
#   'cId': 12},
#  {'linkId': 'WirenBoard/system/On/Integer/Reboot',
#   'controller': 'WirenBoard',
#   'device': 'system',
#   'characteristic': 'On',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'Reboot',
#   'aId': 4,
#   'sId': 10,
#   'cId': 12}]

# %%
ServerLogs = sh.GetServerLogs(12, 3)
ServerLogs
# Out:
# [{'level': 'I',
#   'time': 1578228670322,
#   'date': '12:51:10',
#   'path': 'Homekit.e',
#   'msg': 'publish: 7.13.15/CurrentTemperature/59.9 to 1 clients'},
#  {'level': 'I',
#   'time': 1578228687538,
#   'date': '12:51:27',
#   'path': 'ZigBee.app.c.a',
#   'msg': 'Request: ReadAttributesCommand [Time: C9C7/1 -> 0000/1, cluster=000A, TID=F5, Output, identifiers=[0]]'},
#  {'level': 'I',
#   'time': 1578228687570,
#   'date': '12:51:27',
#   'path': 'ZigBee.app.c.a',
#   'msg': 'Response: ReadAttributesResponse [Time: null -> C9C7/1, cluster=000A, TID=F5, Input, records=[ReadAttributeStatusRecord [status=SUCCESS, attributeIdentifier=0, attributeDataType=UTCTIME, attributeValue=java.util.GregorianCalendar[time=1578228687551,areFieldsSet=true,areAllFieldsSet=true,lenient=true,zone=sun.util.calendar.ZoneInfo[id="Etc/UTC",offset=0,dstSavings=0,useDaylight=false,transitions=0,lastRule=null],firstDayOfWeek=2,minimalDaysInFirstWeek=1,ERA=1,YEAR=2020,MONTH=0,WEEK_OF_YEAR=1,WEEK_OF_MONTH=1,DAY_OF_MONTH=5,DAY_OF_YEAR=5,DAY_OF_WEEK=1,DAY_OF_WEEK_IN_MONTH=1,AM_PM=1,HOUR=0,HOUR_OF_DAY=12,MINUTE=51,SECOND=27,MILLISECOND=551,ZONE_OFFSET=0,DST_OFFSET=0]]]]'}]

# %%
ServersVariables = sh.GetAllServersVariables()
ServersVariables
# Out:
# [{'key': 'Email',
#   'value': 'ghjkl@jdjd.ru',
#   'type': 'string',
#   'en_name': 'Email',
#   'ru_name': 'Почта'},
#  {'key': 'Password',
#   'value': 'raspberry1',
#   'type': 'string',
#   'en_name': 'Password',
#   'ru_name': 'Пароль'},
#  {'key': 'HomekitMac',
#   'value': 'EA:47:9E:F5:E9:F8',
#   'type': 'string',
#   'en_name': 'MAC Address',
#   'ru_name': 'Мак адрес'},
#  {'key': 'HomekitPort',
#   'value': 9123,
#   'type': 'integer',
#   'en_name': 'Port',
#   'ru_name': 'Порт'}]

# %%
ServserVersion = sh.GetServserVersion()
ServserVersion
# Out:
# '1.4.5b'

# %%
ThreadpoolStats = sh.GetThreadpoolStats(True, True)
print(ThreadpoolStats)
# Out:
#  ╒══ General
#  │ ActiveThreads:   0
#  │ CorePoolSize:    0
#  │ MaximumPoolSize: unlimited
#  │ LargestPoolSize: 44
#  │ PoolSize:        4
#  │ CompletedTasks:  233.291
#  │ QueuedTasks:     0
#  ╞══ General Scheduled
#  │ ActiveThreads:   0
#  │ CorePoolSize:    32
#  │ CompletedTasks:  34.352
#  │ ScheduledTasks:  3
#
#
# [1] [Cloud] Ping Task
# [172] [HomeKit] 29.10.12/MotionDetected/false: SwitchOffTime
# [3103] [ZigBee] Mesh Update Task
# Tasks in the queue: 3

# %%
listOfAllAccessories = sh.listOfAllAccessories()
listOfAllAccessories
# Out:
# [{'id': 1,
#   'name': 'SprutHub',
#   'rawName': 'SprutHub',
#   'controller': 'SprutHub',
#   'manufacturer': 'MakeSimple',
#   'serial': '1',
#   'model': 'SprutHub',
#   'firmware': '1.4.5b',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 0},
#  {'id': 2,
#   'name': 'Сигнализация',
#   'rawName': 'Сигнализация',
#   'controller': 'SprutHub',
#   'manufacturer': 'MakeSimple',
#   'serial': '1',
#   'model': 'SecuritySystem',
#   'firmware': '1.4.5b',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578211898584},
#  {'id': 3,
#   'name': 'Выключатель',
#   'rawName': 'Выключатель',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'wb-gpio/A3_OUT',
#   'model': 'I2C',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': True,
#   'lastUpdate': 0},
#  {'id': 4,
#   'name': 'Перезагрузка',
#   'rawName': 'Перезагрузка',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'system',
#   'model': 'System',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': True,
#   'lastUpdate': 0},
#  {'id': 5,
#   'name': 'Аккумулятор',
#   'rawName': 'Аккумулятор',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'power_status',
#   'model': 'System',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 0},
#  {'id': 6,
#   'name': 'Выключатель',
#   'rawName': 'Выключатель',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'wb-gpio/A4_OUT',
#   'model': 'I2C',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': True,
#   'lastUpdate': 0},
#  {'id': 7,
#   'name': 'Системная температура',
#   'rawName': 'Системная температура',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'hwmon',
#   'model': 'System',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578229200345},
#  {'id': 8,
#   'name': 'Выключатель',
#   'rawName': 'Выключатель',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'wb-gpio/A2_OUT',
#   'model': 'I2C',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': True,
#   'lastUpdate': 0},
#  {'id': 9,
#   'name': 'Контакт',
#   'rawName': 'Контакт',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'wb-gpio/A3_IN',
#   'model': 'I2C',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': True,
#   'lastUpdate': 0},
#  {'id': 10,
#   'name': 'Выключатель',
#   'rawName': 'Выключатель',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'wb-gpio/A1_OUT',
#   'model': 'I2C',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': True,
#   'lastUpdate': 0},
#  {'id': 11,
#   'name': 'Контакт',
#   'rawName': 'Контакт',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'wb-gpio/A1_IN',
#   'model': 'I2C',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': True,
#   'lastUpdate': 0},
#  {'id': 12,
#   'name': 'Сирена',
#   'rawName': 'Сирена',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'buzzer',
#   'model': 'System',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 0},
#  {'id': 13,
#   'name': 'Контакт',
#   'rawName': 'Контакт',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'wb-gpio/A4_IN',
#   'model': 'I2C',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': True,
#   'lastUpdate': 0},
#  {'id': 14,
#   'name': 'Контакт',
#   'rawName': 'Контакт',
#   'controller': 'WirenBoard',
#   'manufacturer': 'WirenBoard',
#   'serial': 'wb-gpio/A2_IN',
#   'model': 'I2C',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': True,
#   'lastUpdate': 0},
#  {'id': 15,
#   'name': 'Координатор',
#   'rawName': 'Координатор',
#   'controller': 'ZigBee',
#   'manufacturer': 'TexasInstruments',
#   'serial': '00124B001EC8462E',
#   'model': 'CC253X',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 0},
#  {'id': 16,
#   'name': 'Gen Accessory',
#   'rawName': 'Gen Accessory',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D0001F4E28C',
#   'model': 'lumi.ctrl_86plug.aq1',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578211898602},
#  {'id': 17,
#   'name': 'Дым',
#   'rawName': 'Дым',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00015B7511',
#   'model': 'lumi.sensor_smoke',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 0},
#  {'id': 18,
#   'name': 'Дым',
#   'rawName': 'Дым',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00020B4692',
#   'model': 'lumi.sensor_smoke',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578184929809},
#  {'id': 19,
#   'name': 'Движение и освещённость',
#   'rawName': 'Движение и освещённость',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D0001E542DB',
#   'model': 'lumi.sensor_motion.aq2',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578225948110},
#  {'id': 20,
#   'name': 'Двойной выключатель',
#   'rawName': 'Двойной выключатель',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00022BC8F6',
#   'model': 'lumi.ctrl_neutral2',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 0},
#  {'id': 21,
#   'name': 'Gen Accessory',
#   'rawName': 'Gen Accessory',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D0001F4E40F',
#   'model': 'lumi.ctrl_86plug.aq1',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578211898615},
#  {'id': 22,
#   'name': 'Gen Accessory',
#   'rawName': 'Gen Accessory',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D0001F4E41C',
#   'model': 'lumi.ctrl_86plug.aq1',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 0},
#  {'id': 23,
#   'name': 'Gen Accessory',
#   'rawName': 'Gen Accessory',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D0001F4E415',
#   'model': 'lumi.ctrl_86plug.aq1',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 0},
#  {'id': 24,
#   'name': 'Кнопка',
#   'rawName': 'Кнопка',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00015F2577',
#   'model': 'lumi.sensor_86sw1',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578151856683},
#  {'id': 25,
#   'name': 'Газ метан',
#   'rawName': 'Газ метан',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D000249C585',
#   'model': 'lumi.sensor_natgas',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 0},
#  {'id': 27,
#   'name': 'Контакт',
#   'rawName': 'Контакт',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00011919BA',
#   'model': 'lumi.sensor_magnet',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 0},
#  {'id': 28,
#   'name': 'Контакт',
#   'rawName': 'Контакт',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D0001400613',
#   'model': 'lumi.sensor_magnet',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578224176751},
#  {'id': 29,
#   'name': 'Движение',
#   'rawName': 'Движение',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00015D24C8',
#   'model': 'lumi.sensor_motion',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578229197269},
#  {'id': 30,
#   'name': 'Движение',
#   'rawName': 'Движение',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00019CB1C1',
#   'model': 'lumi.sensor_motion',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578225480923},
#  {'id': 31,
#   'name': 'Розетка',
#   'rawName': 'Розетка',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D0001DEAEF2',
#   'model': 'lumi.plug',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578204161620},
#  {'id': 32,
#   'name': 'Розетка',
#   'rawName': 'Розетка',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D0001DEACAF',
#   'model': 'lumi.plug',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578211898598},
#  {'id': 33,
#   'name': 'Температура и влажность',
#   'rawName': 'Температура и влажность',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00019F8D4A',
#   'model': 'lumi.sensor_ht',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578229030571},
#  {'id': 34,
#   'name': 'Температура и влажность',
#   'rawName': 'Температура и влажность',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00019CB768',
#   'model': 'lumi.sensor_ht',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578229141070},
#  {'id': 35,
#   'name': 'Температура и влажность',
#   'rawName': 'Температура и влажность',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00019F8B90',
#   'model': 'lumi.sensor_ht',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578226561222},
#  {'id': 36,
#   'name': 'Температура и влажность',
#   'rawName': 'Температура и влажность',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D0001A2A8F1',
#   'model': 'lumi.sensor_ht',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578225293217},
#  {'id': 37,
#   'name': 'Кнопка',
#   'rawName': 'Кнопка',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00023D326B',
#   'model': 'lumi.sensor_switch',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 0},
#  {'id': 38,
#   'name': 'Розетка',
#   'rawName': 'Розетка',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00015C7ACF',
#   'model': 'lumi.plug',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578211898625},
#  {'id': 39,
#   'name': 'Температура и влажность',
#   'rawName': 'Температура и влажность',
#   'controller': 'ZigBee',
#   'manufacturer': 'LUMI',
#   'serial': '00158D00019C8EA5',
#   'model': 'lumi.sensor_ht',
#   'firmware': '-',
#   'roomId': 0,
#   'roomName': '-',
#   'hidden': False,
#   'lastUpdate': 1578228534532}]

# %%
InfoAboutAccessory = sh.InfoAboutAccessory(32)
InfoAboutAccessory
# Out:
# {'id': 32,
#  'name': 'Розетка',
#  'rawName': 'Розетка',
#  'controller': 'ZigBee',
#  'manufacturer': 'LUMI',
#  'serial': '00158D0001DEACAF',
#  'model': 'lumi.plug',
#  'firmware': '-',
#  'roomId': 0,
#  'roomName': '-',
#  'hidden': False,
#  'lastUpdate': 1578211898598}

# %%
sh.CreatesNewAccessoryAndService('new_acc', 'Штора')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-11-e2c0940eccac> in <module>
# ----> 1 sh.CreatesNewAccessoryAndService('new_acc', 'Штора')
#
# ~/Desktop/spruthub/spruthub.py in CreatesNewAccessoryAndService(self, name, serviceType)
#     127         answer = requests.post(
#     128             url=url, headers={'accept': '*/*', 'Content-Type': '*/*'}, cookies=self.cookie, timeout=0.5)
# --> 129         answer.raise_for_status()
#     130
#     131     def HideShowAccessory(self, aid, value):
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     938
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#     942     def close(self):
#
# HTTPError: 500 Server Error: Internal Server Error for url: http://192.168.31.133:55555/api/accessories/new_acc/%D0%A8%D1%82%D0%BE%D1%80%D0%B0

# %%
sh.HideShowAccessory(2, False)

# %%
sh.SetAccessoryName(39, 'Температура и влажность')

# %%
sh.listOfAllServicesOfAccessory(10)
# Out:
# [{'a_id': 10,
#   'id': 10,
#   'name': 'Выключатель',
#   'rawName': 'Выключатель',
#   'cl': 'Switch',
#   'homekitType': 'Switch',
#   'homekitType_en': 'Switch',
#   'homekitType_ru': 'Выключатель',
#   'googleType': 'Switch',
#   'googleAttributes': '{}',
#   'yandexType': 'Switch',
#   'data': {},
#   'hidden': False}]

# %%
sh.listOfAllCharacteristicsOfOneServiceAndAccessory(32, 10)
# Out:
# [{'a_id': 32,
#   's_id': 10,
#   'id': 13,
#   'cl': 'OutletInUse',
#   'type': 'OutletInUse',
#   'type_en': 'In Use',
#   'type_ru': 'Используется',
#   'trait': '-',
#   'capability': '-',
#   'format': 'bool',
#   'writable': False,
#   'readable': True,
#   'description': '',
#   'minValue': None,
#   'maxValue': None,
#   'minStep': None,
#   'validValues': [{'id': 'false',
#     'name_en': 'Not in use',
#     'name_ru': 'Нет',
#     'checked': False},
#    {'id': 'true', 'name_en': 'In use', 'name_ru': 'Да', 'checked': False}],
#   'data': {},
#   'link': None,
#   'triggers': [],
#   'value': 'false'},
#  {'a_id': 32,
#   's_id': 10,
#   'id': 12,
#   'cl': 'On',
#   'type': 'On',
#   'type_en': 'On',
#   'type_ru': 'Включен',
#   'trait': 'OnOff',
#   'capability': 'on_off',
#   'format': 'bool',
#   'writable': True,
#   'readable': True,
#   'description': '',
#   'minValue': None,
#   'maxValue': None,
#   'minStep': None,
#   'validValues': None,
#   'data': {'Inversed': False, 'SwitchOffTime': 0},
#   'link': {'linkId': 'ZigBee/00158D0001DEACAF/On/Boolean/1/OnOff/State',
#    'controller': 'ZigBee',
#    'device': '00158D0001DEACAF',
#    'characteristic': 'On',
#    'type': 'Boolean',
#    'value': 'true',
#    'params': '1/OnOff/State',
#    'aId': 32,
#    'sId': 10,
#    'cId': 12},
#   'triggers': [],
#   'value': 'true'}]

# %%
sh.InfoAboutOneCharacteristic(10, 12)
# Out:
# {'a_id': 10,
#  's_id': 10,
#  'id': 12,
#  'cl': 'On',
#  'type': 'On',
#  'type_en': 'On',
#  'type_ru': 'Включен',
#  'trait': 'OnOff',
#  'capability': 'on_off',
#  'format': 'bool',
#  'writable': True,
#  'readable': True,
#  'description': '',
#  'minValue': None,
#  'maxValue': None,
#  'minStep': None,
#  'validValues': None,
#  'data': {'Inversed': False, 'SwitchOffTime': 0},
#  'link': {'linkId': 'WirenBoard/wb-gpio/On/Integer/A1_OUT',
#   'controller': 'WirenBoard',
#   'device': 'wb-gpio',
#   'characteristic': 'On',
#   'type': 'Integer',
#   'value': '0',
#   'params': 'A1_OUT',
#   'aId': 10,
#   'sId': 10,
#   'cId': 12},
#  'triggers': [],
#  'value': 'false'}

# %%
sh.SetСharacteristicValue(38, 12, 'true')
